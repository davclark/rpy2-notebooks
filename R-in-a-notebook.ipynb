# %%
import sys
import rpy2
print('python:', sys.version)
print('rpy2:', rpy2.__version__)

# Make rpy2 nice to work with R in the notebook
# Note that this automatically activates pandas2ri or numpy2ri if it can
# %load_ext rpy2.ipython
# Out:
# python: 3.4.2 |Continuum Analytics, Inc.| (default, Oct 21 2014, 17:42:20)
# [GCC 4.2.1 (Apple Inc. build 5577)]
# rpy2: 2.5.3
# The rpy2.ipython extension is already loaded. To reload it, use:
#   %reload_ext rpy2.ipython

# %%
import rpy2.robjects as ro
import pandas as pd
from rpy2.robjects.conversion import ri2py

# %% [markdown]
# ## Use a line magic

# %%
df = %R data.frame(a=c(2,2), b=c('this', 'that'))
df
# Out:
# <DataFrame - Python:0x10bc49248 / R:0x1022dd0d8>
# [FloatVector, FactorVector]
#   a: <class 'rpy2.robjects.vectors.FloatVector'>
#   <FloatVector - Python:0x10bc49e48 / R:0x1022cb9f0>
# [2.000000, 2.000000]
#   b: <class 'rpy2.robjects.vectors.FactorVector'>
#   <FactorVector - Python:0x10bc48248 / R:0x103e13db8>
# [       2,        1]

# %%
print(df)
# Out:
#   a    b
# 1 2 this
# 2 2 that

# %%
print(df.rx(1,True))
# Out:
#   a    b
# 1 2 this

# %%
ri2py(df)
# Out:
#    a     b
# 0  2  this
# 1  2  that

# %%
type(df)
# Out:
# rpy2.robjects.vectors.DataFrame

# %%
type(ri2py(df))
# Out:
# pandas.core.frame.DataFrame

# %% [markdown]
# ## Use a cell magic

# %%
# %%R -o df2
#
# df2 <- data.frame(a=c(2,2),
#                   b=c('this', 'that'))

# %%
ri2py(df2)
# Out:
#    a     b
# 0  2  this
# 1  2  that

# %% [markdown]
# ## Pass a code string to R directly
#
# This is probably the best way to do things in a script

# %%
df3 = ro.r("data.frame(a=c(2,2), b=c('this', 'that'))")

# %%
ri2py(df3)
# Out:
#    a     b
# 0  2  this
# 1  2  that

# %% [markdown]
# # Data can easily go the other way

# %%
import numpy as np
a = np.arange(0, 20,0.05)
b = np.sin(a)
pdf = pd.DataFrame({'a': a, 'b': b})

# %%
pdf.dtypes
# Out:
# a    float64
# b    float64
# dtype: object

# %%
# %%R -i pdf
# plot(b ~ a, pdf, type='l')

# %%
ro.r.svg('plot.svg')
ro.r.plot(pdf.b, type='l')
ro.r('dev.off()')
# Out:
# <IntVector - Python:0x10f146848 / R:0x1044f3e98>
# [       2]

# %%
from IPython.display import SVG
SVG(filename='plot.svg')

# %% [markdown]
# # This will eventually be examples in blaze
#
# Move along now, nothing to see here

# %%
from dynd import nd
nd.array([1, None])
# Out:
# nd.array([ 1, NA],
#          type="strided * ?int32")

# %%
import numpy as np
x = np.array([1, np.nan])

# %%
x
# Out:
# array([  1.,  nan])

# %%
nd.array(x, dtype="?int")
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# <ipython-input-25-0bf47e3bd09e> in <module>()
# ----> 1 nd.array(x, dtype="?int")
#
# /opt/anaconda/envs/blaze/lib/python2.7/site-packages/dynd/_pydynd.so in dynd._pydynd.w_array.__init__ (/private/var/jenkins/workspace/DyND-Python/PLATFORM/osxbuild/PYTHON_VERSION/2.7/build/dynd._pydynd.cxx:7368)()
#
# RuntimeError: fractional part lost while assigning float64 value nan to int32
